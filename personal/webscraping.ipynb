# %%
from bs4 import BeautifulSoup as bs
import requests
import numpy as np
import pandas as pd
import csv
from itertools import zip_longest
import matplotlib.pyplot as plt
import tracemalloc
import html5lib

# %%
import time
time.sleep(3)

# %%
page = 1
b=[]
a=[]
c1=[]
c2=[]
district_=[]
district=[]
link=[]
rooms=[]
while page != 3:
        url = f"https://sa.aqar.fm/%D8%B4%D9%82%D9%82-%D9%84%D9%84%D8%A5%D9%8A%D8%AC%D8%A7%D8%B1/%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6/{page}?rent_type=3"
        response = requests.get(url)
        html = response.content
        soup = bs(html, "lxml")
        price=soup.find_all('div', class_='listingCard-module_price__xxySC')
        for i in range(len(price)):
            b.append(price[i].text) 
        District=soup.find_all('h4', class_='listingCard-module_title__ngUkH listingCard-module_truncatedText__WCRqD')
        for i in range(len(District)):
            district.append(District[i].text)
        tittle=soup.find_all("h4",{"class":"listingCard-module_title__ngUkH listingCard-module_truncatedText__WCRqD"})
        
        room=soup.find_all('h4', class_='listingCard-module_spec__oTAMM')
        for i in range(len(District)):
            rooms.append(District[i].text)
       
        
        for i in range(len(tittle)):
            try:
                link.append("https://sa.aqar.fm"+tittle[i].find("a").attrs['href'])
            except:
                pass
        time.sleep(3)   
        page = page + 1

# %%
# Out:
# [<div class="listingCard-module_price__xxySC">23,000 ريال</div>,
#  <div class="listingCard-module_price__xxySC">19,000 ريال</div>,
#  <div class="listingCard-module_price__xxySC">26,000 ريال</div>,
#  <div class="listingCard-module_price__xxySC">120,000 ريال</div>,
#  <div class="listingCard-module_price__xxySC">40,000 ريال</div>,
#  <div class="listingCard-module_price__xxySC">20,000 ريال</div>,
#  <div class="listingCard-module_price__xxySC">19,000 ريال</div>,
#  <div class="listingCard-module_price__xxySC">80,000 ريال</div>,
#  <div class="listingCard-module_price__xxySC">165,000 ريال</div>,
#  <div class="listingCard-module_price__xxySC">80,000 ريال</div>,
#  <div class="listingCard-module_price__xxySC">65,000 ريال</div>,
#  <div class="listingCard-module_price__xxySC">70,000 ريال</div>,
#  <div class="listingCard-module_price__xxySC">85,000 ريال</div>,
#  <div class="listingCard-module_price__xxySC">90,000 ريال</div>,
# ...

# %%
for i in range(len(district)):
        district_.append(district[i].split("،"))
district__=pd.DataFrame(district_)
districts=district__[1]

# %%
f=[b,districts,link]

# %%
# f=[b,districts,link]
# ex=zip_longest(*f)

# %%
# with open("part5.csv","w",encoding="utf-8") as my:
#     wr=csv.writer(my)
#     wr.writerow(["Price","Districts","Link"])
#     wr.writerows(ex)

# %%
df = pd.read_csv('./part5.csv')

# %%
df
# Out:
#            Price                      Districts  \
# 0    90,000 ريال                     حي الملقا
# 1   165,000 ريال                        الرياض
# 2    26,000 ريال                    حي اليرموك
# 3    31,000 ريال                    حي الحمراء
# 4    32,000 ريال                    حي اليرموك
# 5    50,000 ريال                     حي الربوة
# 6    68,000 ريال                     حي العليا
# 7    25,000 ريال                     حي المروج
# 8    50,000 ريال                     حي المربع
# 9    65,000 ريال                    حي الصحافة
# 10   53,000 ريال                     حي العليا
# 11   90,000 ريال             شارع عبدالله غازي
# 12  150,000 ريال                     حي العليا
# 13   88,000 ريال                        الرياض
# 14  350,000 ريال                     حي العليا
# 15  165,000 ريال                     حي العليا
# 16  220,000 ريال                     حي العليا
# 17  115,000 ريال                        الرياض
# 18   80,000 ريال                     حي غرناطة
# ...

# %%
from selenium import webdriver

browser = webdriver.Firefox()
browser.get('http://selenium.dev/')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/conda/lib/python3.9/site-packages/selenium/webdriver/common/service.py:71, in Service.start(self)
#      70     cmd.extend(self.command_line_args())
# ---> 71     self.process = subprocess.Popen(cmd, env=self.env,
#      72                                     close_fds=system() != 'Windows',
#      73                                     stdout=self.log_file,
#      74                                     stderr=self.log_file,
#      75                                     stdin=PIPE,
#      76                                     creationflags=self.creationflags)
#      77 except TypeError:
#
# ...
