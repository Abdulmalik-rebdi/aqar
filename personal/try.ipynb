# %%
from bs4 import BeautifulSoup as bs
import requests
import numpy as np
import pandas as pd
import csv
from itertools import zip_longest
import matplotlib.pyplot as plt
import tracemalloc
import html5lib

# %%
df = pd.read_csv('./part5.csv')

# %%
cookies = {
    '_ga': 'GA1.2.949437841.1658053335',
    'user_about': '%22%22',
    'user_iam_verified': '%22%22',
    'user_id': '2635838',
    'user_img': '%22%22',
    'user_listings': '%22%22',
    'user_phone': '555657442',
    'user_rega_approved': '%22%22',
    'user_type': 'null',
    'webapp_token': '%22WUYgwXXZvKBD6pf1MVIMUe-8AHNSUlfZDZZBWTC7lunH6YfBBwn2IPRUbUiU6r9EMRoyCnBZEo9JBbnM8zJGD7iq7BRiSk3DrhFcPlf7-Ao4pSx4iqn91BlKe5Z38oD0MhVZBBqsIdOerilCKbonKZEKhmpEqNVabtd9JZFvn48H%22',
    'user_chosen_user_type': '%22seeker%22',
    'user_email': '%22Abdulmalik.rebdi@gmail.com%22',
    'user_favs': 'undefined',
    'user_name': '%22%D8%B9%D8%A8%D8%AF%D8%A7%D9%84%D9%85%D9%84%D9%83%20%D9%85%D8%AD%D9%85%D8%AF%22',
    '_gac_UA-52229618-6': '1.1658215605.CjwKCAjwrNmWBhA4EiwAHbjEQKFQz1rx6FuVoKZ5qMiLIw0KssIfM2AiYdQaJgoOj5gwQPkQRCyvAxoC4sUQAvD_BwE',
    '_gid': 'GA1.2.1905218404.1659014646',
    '_gat': '1',
    'AWSALBTG': 'kR2HN7VT/PwaEbZUpFYGUoaGWmKgRck6rcYRVoVHGykNSx5AwnutNS7N+0VTrU1eJQWg4K12v6SKT3sGXpCcoDHjxU48lGTmQCBOntKbVf1xkNIwOil/Y7MxeuY4vI8tFNsnN34+bcL9NN8ERw8kpbuiDIyn3h8VfkggCW3FwzWvkjcs8LE=',
    'AWSALBTGCORS': 'kR2HN7VT/PwaEbZUpFYGUoaGWmKgRck6rcYRVoVHGykNSx5AwnutNS7N+0VTrU1eJQWg4K12v6SKT3sGXpCcoDHjxU48lGTmQCBOntKbVf1xkNIwOil/Y7MxeuY4vI8tFNsnN34+bcL9NN8ERw8kpbuiDIyn3h8VfkggCW3FwzWvkjcs8LE=',
}

headers = {
    'authority': 'sa.aqar.fm',
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9,ar;q=0.8',
    'app-version': '0.16.6',
    # Already added when you pass json=
    # 'content-type': 'application/json',
    # Requests sorts cookies= alphabetically
    # 'cookie': '_ga=GA1.2.949437841.1658053335; user_about=%22%22; user_iam_verified=%22%22; user_id=2635838; user_img=%22%22; user_listings=%22%22; user_phone=555657442; user_rega_approved=%22%22; user_type=null; webapp_token=%22WUYgwXXZvKBD6pf1MVIMUe-8AHNSUlfZDZZBWTC7lunH6YfBBwn2IPRUbUiU6r9EMRoyCnBZEo9JBbnM8zJGD7iq7BRiSk3DrhFcPlf7-Ao4pSx4iqn91BlKe5Z38oD0MhVZBBqsIdOerilCKbonKZEKhmpEqNVabtd9JZFvn48H%22; user_chosen_user_type=%22seeker%22; user_email=%22Abdulmalik.rebdi@gmail.com%22; user_favs=undefined; user_name=%22%D8%B9%D8%A8%D8%AF%D8%A7%D9%84%D9%85%D9%84%D9%83%20%D9%85%D8%AD%D9%85%D8%AF%22; _gac_UA-52229618-6=1.1658215605.CjwKCAjwrNmWBhA4EiwAHbjEQKFQz1rx6FuVoKZ5qMiLIw0KssIfM2AiYdQaJgoOj5gwQPkQRCyvAxoC4sUQAvD_BwE; _gid=GA1.2.1905218404.1659014646; _gat=1; AWSALBTG=kR2HN7VT/PwaEbZUpFYGUoaGWmKgRck6rcYRVoVHGykNSx5AwnutNS7N+0VTrU1eJQWg4K12v6SKT3sGXpCcoDHjxU48lGTmQCBOntKbVf1xkNIwOil/Y7MxeuY4vI8tFNsnN34+bcL9NN8ERw8kpbuiDIyn3h8VfkggCW3FwzWvkjcs8LE=; AWSALBTGCORS=kR2HN7VT/PwaEbZUpFYGUoaGWmKgRck6rcYRVoVHGykNSx5AwnutNS7N+0VTrU1eJQWg4K12v6SKT3sGXpCcoDHjxU48lGTmQCBOntKbVf1xkNIwOil/Y7MxeuY4vI8tFNsnN34+bcL9NN8ERw8kpbuiDIyn3h8VfkggCW3FwzWvkjcs8LE=',
    'dpr': '1.1',
    'origin': 'https://sa.aqar.fm',
    'referer': 'https://sa.aqar.fm/%D8%B4%D9%82%D9%82-%D9%84%D9%84%D8%A5%D9%8A%D8%AC%D8%A7%D8%B1/%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6/%D8%B4%D9%85%D8%A7%D9%84-%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6?rent_type=3',
    'req-app': 'web',
    'req-device-token': '81c80c83-eccd-41cb-8a4b-8184a7be9754',
    'sec-ch-ua': '".Not/A)Brand";v="99", "Google Chrome";v="103", "Chromium";v="103"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36',
    'viewport-width': '1395',
}

        json_data = {
            'operationName': 'findListings',
            'variables': {
                'size': 20,
                'from': i, ## the page
                'sort': {
                    'create_time': 'desc',
                    'has_img': 'desc',
                },
                'where': {
                    'category': {
                        'eq': 1, ## catg (apartment , land)
                    },
                    'city_id': {
                        'eq': 21, ## city (jeddah , riyadh)
                    },
                    # 'direction_id': { 
                    #     'eq': 7, #{1 : riyadhSouth , 3:  east  , 4 : north,  7:middle }
                    # },
                    'rent_period': {
                        'eq': 3, # {1 , daily  , 2 : monthly , 3: yearly }
                    },
                },
            },
            'query': 'query findListings($size: Int, $from: Int, $sort: SortInput, $where: WhereInput, $polygon: [LocationInput!]) {\n  Web {\n    find(size: $size, from: $from, sort: $sort, where: $where, polygon: $polygon) {\n      ...WebResults\n      __typename\n    }\n    __typename\n  }\n}\n\nfragment WebResults on WebResults {\n  listings {\n    user_id\n    id\n    uri\n    title\n    price\n    content\n    imgs\n    refresh\n    category\n    beds\n    livings\n    wc\n    area\n    type\n    street_width\n    age\n    last_update\n    street_direction\n    ketchen\n    ac\n    furnished\n    location {\n      lat\n      lng\n      __typename\n    }\n    path\n    user {\n      review\n      img\n      name\n      phone\n      iam_verified\n      rega_id\n      __typename\n    }\n    native {\n      logo\n      title\n      image\n      description\n      external_url\n      __typename\n    }\n    rent_period\n    city\n    district\n    width\n    length\n    advertiser_type\n    create_time\n    __typename\n  }\n  total\n  __typename\n}\n',
        }

        response = requests.post('https://sa.aqar.fm/graphql', cookies=cookies, headers=headers, json=json_data)
# Out:
#   Input In [72]
#     response = requests.post('https://sa.aqar.fm/graphql', cookies=cookies, headers=headers, json=json_data)
#                                                                                                             ^
# SyntaxError: unexpected EOF while parsing

# %%
result = []
result = pd.DataFrame(result)
result
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
i = 0

# %%
cookies = {
    '_ga': 'GA1.2.949437841.1658053335',
    'user_about': '%22%22',
    'user_iam_verified': '%22%22',
    'user_id': '2635838',
    'user_img': '%22%22',
    'user_listings': '%22%22',
    'user_phone': '555657442',
    'user_rega_approved': '%22%22',
    'user_type': 'null',
    'webapp_token': '%22WUYgwXXZvKBD6pf1MVIMUe-8AHNSUlfZDZZBWTC7lunH6YfBBwn2IPRUbUiU6r9EMRoyCnBZEo9JBbnM8zJGD7iq7BRiSk3DrhFcPlf7-Ao4pSx4iqn91BlKe5Z38oD0MhVZBBqsIdOerilCKbonKZEKhmpEqNVabtd9JZFvn48H%22',
    'user_chosen_user_type': '%22seeker%22',
    'user_email': '%22Abdulmalik.rebdi@gmail.com%22',
    'user_favs': 'undefined',
    'user_name': '%22%D8%B9%D8%A8%D8%AF%D8%A7%D9%84%D9%85%D9%84%D9%83%20%D9%85%D8%AD%D9%85%D8%AF%22',
    '_gac_UA-52229618-6': '1.1658215605.CjwKCAjwrNmWBhA4EiwAHbjEQKFQz1rx6FuVoKZ5qMiLIw0KssIfM2AiYdQaJgoOj5gwQPkQRCyvAxoC4sUQAvD_BwE',
    '_gid': 'GA1.2.1905218404.1659014646',
    '_gat': '1',
    'AWSALBTG': 'kR2HN7VT/PwaEbZUpFYGUoaGWmKgRck6rcYRVoVHGykNSx5AwnutNS7N+0VTrU1eJQWg4K12v6SKT3sGXpCcoDHjxU48lGTmQCBOntKbVf1xkNIwOil/Y7MxeuY4vI8tFNsnN34+bcL9NN8ERw8kpbuiDIyn3h8VfkggCW3FwzWvkjcs8LE=',
    'AWSALBTGCORS': 'kR2HN7VT/PwaEbZUpFYGUoaGWmKgRck6rcYRVoVHGykNSx5AwnutNS7N+0VTrU1eJQWg4K12v6SKT3sGXpCcoDHjxU48lGTmQCBOntKbVf1xkNIwOil/Y7MxeuY4vI8tFNsnN34+bcL9NN8ERw8kpbuiDIyn3h8VfkggCW3FwzWvkjcs8LE=',
}

headers = {
    'authority': 'sa.aqar.fm',
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9,ar;q=0.8',
    'app-version': '0.16.6',
    # Already added when you pass json=
    # 'content-type': 'application/json',
    # Requests sorts cookies= alphabetically
    # 'cookie': '_ga=GA1.2.949437841.1658053335; user_about=%22%22; user_iam_verified=%22%22; user_id=2635838; user_img=%22%22; user_listings=%22%22; user_phone=555657442; user_rega_approved=%22%22; user_type=null; webapp_token=%22WUYgwXXZvKBD6pf1MVIMUe-8AHNSUlfZDZZBWTC7lunH6YfBBwn2IPRUbUiU6r9EMRoyCnBZEo9JBbnM8zJGD7iq7BRiSk3DrhFcPlf7-Ao4pSx4iqn91BlKe5Z38oD0MhVZBBqsIdOerilCKbonKZEKhmpEqNVabtd9JZFvn48H%22; user_chosen_user_type=%22seeker%22; user_email=%22Abdulmalik.rebdi@gmail.com%22; user_favs=undefined; user_name=%22%D8%B9%D8%A8%D8%AF%D8%A7%D9%84%D9%85%D9%84%D9%83%20%D9%85%D8%AD%D9%85%D8%AF%22; _gac_UA-52229618-6=1.1658215605.CjwKCAjwrNmWBhA4EiwAHbjEQKFQz1rx6FuVoKZ5qMiLIw0KssIfM2AiYdQaJgoOj5gwQPkQRCyvAxoC4sUQAvD_BwE; _gid=GA1.2.1905218404.1659014646; _gat=1; AWSALBTG=kR2HN7VT/PwaEbZUpFYGUoaGWmKgRck6rcYRVoVHGykNSx5AwnutNS7N+0VTrU1eJQWg4K12v6SKT3sGXpCcoDHjxU48lGTmQCBOntKbVf1xkNIwOil/Y7MxeuY4vI8tFNsnN34+bcL9NN8ERw8kpbuiDIyn3h8VfkggCW3FwzWvkjcs8LE=; AWSALBTGCORS=kR2HN7VT/PwaEbZUpFYGUoaGWmKgRck6rcYRVoVHGykNSx5AwnutNS7N+0VTrU1eJQWg4K12v6SKT3sGXpCcoDHjxU48lGTmQCBOntKbVf1xkNIwOil/Y7MxeuY4vI8tFNsnN34+bcL9NN8ERw8kpbuiDIyn3h8VfkggCW3FwzWvkjcs8LE=',
    'dpr': '1.1',
    'origin': 'https://sa.aqar.fm',
    'referer': 'https://sa.aqar.fm/%D8%B4%D9%82%D9%82-%D9%84%D9%84%D8%A5%D9%8A%D8%AC%D8%A7%D8%B1/%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6/%D8%B4%D9%85%D8%A7%D9%84-%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6?rent_type=3',
    'req-app': 'web',
    'req-device-token': '81c80c83-eccd-41cb-8a4b-8184a7be9754',
    'sec-ch-ua': '".Not/A)Brand";v="99", "Google Chrome";v="103", "Chromium";v="103"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36',
    'viewport-width': '1395',
}

# while True : 
json_data = {
    'operationName': 'findListings',
    'variables': {
        'size': 1,
        'from': 0, ## the page
        'sort': {
            'create_time': 'desc',
            'has_img': 'desc',
        },
        'where': {
            'category': {
                'eq': 1, ## catg (apartment , land)
            },
            'city_id': {
                'eq': 21, ## city (jeddah , riyadh)
            },
            # 'direction_id': { 
            #     'eq': 7, #{1 : riyadhSouth , 3:  east  , 4 : north,  7:middle }
            # },
            'rent_period': {
                'eq': 3, # {1 , daily  , 2 : monthly , 3: yearly }
            },
        },
    },
    'query': 'query findListings($size: Int, $from: Int, $sort: SortInput, $where: WhereInput, $polygon: [LocationInput!]) {\n  Web {\n    find(size: $size, from: $from, sort: $sort, where: $where, polygon: $polygon) {\n      ...WebResults\n      __typename\n    }\n    __typename\n  }\n}\n\nfragment WebResults on WebResults {\n  listings {\n    user_id\n    id\n    uri\n    title\n    price\n    content\n    imgs\n    refresh\n    category\n    beds\n    livings\n    wc\n    area\n    type\n    street_width\n    age\n    last_update\n    street_direction\n    ketchen\n    ac\n    furnished\n    location {\n      lat\n      lng\n      __typename\n    }\n    path\n    user {\n      review\n      img\n      name\n      phone\n      iam_verified\n      rega_id\n      __typename\n    }\n    native {\n      logo\n      title\n      image\n      description\n      external_url\n      __typename\n    }\n    rent_period\n    city\n    district\n    width\n    length\n    advertiser_type\n    create_time\n    __typename\n  }\n  total\n  __typename\n}\n',
}

response = requests.post('https://sa.aqar.fm/graphql', cookies=cookies, headers=headers, json=json_data)
result1 = response.json()
result1= result1.get('data')
result1= result1.get('Web')
result1= result1.get('find')
result1= result1.get('listings')
result1 = pd.DataFrame(result1)

# if result[0] == result1[0] :
#     break
# result1 = pd.DataFrame(result1)
result = result.append(result1, ignore_index=True)
i+=1
# Out:
# /tmp/ipykernel_29392/3370893829.py:86: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(result1, ignore_index=True)

# %%
# Out:
# True

# %%
list(result.iloc[0])[0]
# Out:
# 849984

# %%
result['type']
# Out:
# 0    None
# Name: type, dtype: object

# %%
result
# Out:
#     user_id       id                                                uri  \
# 0   2092599  4504656       شارع-الدوحة-حي-الشهداء-الرياض-الرياض-4504656
# 1   2624685  4509994      شارع-البغدادي-حي-الريان-الرياض-الرياض-4509994
# 2    989070  4489183  شارع-أحمد-بن-قطرب-حي-المهدية-الرياض-الرياض-448...
# 3    940589  4470205  شارع-عبدالوهاب-عرب-حي-العارض-الرياض-الرياض-447...
# 4   2402137  4550231       شارع-وادي-وج-حي-الملقا-الرياض-الرياض-4550231
# 5    970629  4540798   شارع-محمد-العقبي-حي-النرجس-الرياض-الرياض-4540798
# 6   1992649  4563675  شارع-شهيد-الدين-ثم-الوطن-عبدالرحمن-بن-عزاز-حي-...
# 7    104193  4548168    شارع-القادسية-حي-الياسمين-الرياض-الرياض-4548168
# 8   2436416  4278960                    الرياض-حي-الربيع-الرياض-4278960
# 9   1732110  4436949  شارع-ربيعة-الثقفي-حي-النزهة-الرياض-الرياض-4436949
# 10   422265   825676                 شارع-الكهف-حي-السلام-الرياض-825676
# 11   151349  4428559       شارع-البيان-حي-السعادة-الرياض-الرياض-4428559
# ...

# %%
d
# Out:
# ['3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3',
#  '3']

# %%
unique(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /workspaces/projects/try.ipynb Cell 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://dev-container%2B633a5c55736572735c646776616666616661655c70726f6a65637473/workspaces/projects/try.ipynb#ch0000004vscode-remote?line=0'>1</a> unique(x)
#
# NameError: name 'unique' is not defined

# %%
def unique(list1):
 
    # initialize a null list
    unique_list = []
 
    # traverse for all elements
    for x in list1:
        # check if exists in unique_list or not
        if x not in unique_list:
            unique_list.append(x)
    # print list
    for x in unique_list:
        print(x)

# %%
a
# Out:
# []

# %%
unique(a)

# %%
df.Link[4]
# Out:
# 'https://sa.aqar.fm/%D8%B4%D9%82%D9%82-%D9%84%D9%84%D8%A5%D9%8A%D8%AC%D8%A7%D8%B1/%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6/%D8%B4%D8%B1%D9%82-%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6/%D8%AD%D9%8A-%D8%A7%D9%84%D9%8A%D8%B1%D9%85%D9%88%D9%83/%D8%B4%D8%A7%D8%B1%D8%B9-%D9%86%D9%82%D8%B9%D9%87-%D8%AD%D9%8A-%D8%A7%D9%84%D9%8A%D8%B1%D9%85%D9%88%D9%83-%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6-%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6-4499156'
